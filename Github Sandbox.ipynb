# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 

x = np.arange(0,10,0.1)
y = np.exp(x)

plt.plot(x,y)
plt.xlabel('Time (Months post-Graduation)')
plt.ylabel('Wealth (Millions)')
plt.title('Combined Networth of Sherry, Nicolas, Trilok, and Romain')
plt.show()

# %%
###RUN THIS PART ONLY IF U HAVE WINDOWS 10
import os
import win32com.client as wincl
speak = wincl.Dispatch("SAPI.SpVoice")
speak.Speak("baby shark dododododo - baby shark dododododo - baby shark dododododo - baby shark")
# Out:
# 1
